# %%
import pandas as pd

# %%
address = '../kişi_başına_gayri_safi_milli_hasıla/kişi_başına_gayri_safi_milli_hasıla.xls'
data = pd.read_excel(address)
data.head(20)
# Out:
#                                            Unnamed: 0  \
# 0                                            Satırlar
# 1                                                 NaN
# 2                                                 NaN
# 3   Kişi Başına Gayri Safi Yurtiçi Hasıla (2009 Ba...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   para_birimi  50 non-null     object
#  1   yil          50 non-null     int32
#  2   deger        50 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 932.0+ bytes

# %%
data = data.loc[data.index > 2]

# %%
data = data.reset_index(drop=True)

# %%
data.loc[0 : 24, 'Unnamed: 1'] = 'USD'

# %%
data.loc[25 : , 'Unnamed: 1'] = 'TL'

# %%
data = data.loc[:, data.columns != 'Unnamed: 0']

# %%
data.columns = ['para_birimi', 'yil', 'deger']

# %%
data['yil'] = data['yil'].astype('int')
data['deger'] = data['deger'].astype('int')

# %%
data
# Out:
#    para_birimi   yil   deger
# 0          USD  1998    4445
# 1          USD  1999    4010
# 2          USD  2000    4249
# 3          USD  2001    3108
# 4          USD  2002    3608
# 5          USD  2003    4739
# 6          USD  2004    6021
# 7          USD  2005    7376
# 8          USD  2006    7971
# 9          USD  2007    9735
# 10         USD  2008   11018
# 11         USD  2009    9044
# 12         USD  2010   10629
# 13         USD  2011   11289
# 14         USD  2012   11675
# 15         USD  2013   12582
# 16         USD  2014   12178
# 17         USD  2015   11085
# 18         USD  2016   10964
# 19         USD  2017   10696
# 20         USD  2018    9799
# 21         USD  2019    9208
# 22         USD  2020    8600
# 23         USD  2021    9601
# 24         USD  2022   10659
# 25          TL  1998    1152
# 26          TL  1999    1695
# 27          TL  2000    2668
# 28          TL  2001    3794
# 29          TL  2002    5486
# 30          TL  2003    7069
# ...

# %%
data.to_csv('C:/Users/Tacab/Desktop/dashboard_projesi_ile_alakalı/kişi_başına_gayri_safi_milli_hasıla/turkey_cleaned_gdp_per_capita.csv', index=False)
